# %%
# !pip install onnx
# !pip install onnx-graphsurgeon
# !pip install onnxsim
# !pip install simple_onnx_processing_tools
# !pip install onnx2tf
# !pip install -U \
torch \
torchvision \
pandas \
opencv-python \
tqdm \
pyyaml \
matplotlib \
seaborn \
scipy \
coremltools \
onnxruntime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 72.5 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 23.9 MB/s eta 0:00:00
# ...

# %%
# !python3 -m pip install onnx_graphsurgeon --index-url https://pypi.ngc.nvidia.com
# Out:
# Looking in indexes: https://pypi.ngc.nvidia.com, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 3.2 MB/s eta 0:00:00
# ...

# %%
# !sudo add-apt-repository -y ppa:deadsnakes/ppa
# !sudo apt-get -y update
# !sudo apt-get -y install python3.9-dev
# !sudo apt-get -y install python3-pip
# !sudo apt-get -y install python3.9-distutils
# !python3.9 -m pip install tensorflow==2.10.0 \
  && python3.9 -m pip install -U onnx \
  && python3.9 -m pip install -U onnx-graphsurgeon \
  && python3.9 -m pip install -U onnxsim \
  && python3.9 -m pip install -U simple_onnx_processing_tools \
  && python3.9 -m pip install -U onnx2tf \
# !python3.9 -m pip install -U \
torch \
torchvision \
pandas \
opencv-python \
tqdm \
pyyaml \
matplotlib \
seaborn \
scipy \
coremltools \
onnxruntime
# !python3.9 -m onnx2tf -i "/content/drive/MyDrive/TestTask/model.onnx" -cotof -cotoa 1e-1

# %%
# !python3 -m onnx2tf -i "/content/drive/MyDrive/TestTask/model.onnx" -kt KEEP_NWC_OR_NHWC_OR_NDHWC_INPUT_NAMES -kat KEEP_SHAPE_ABSOLUTELY_INPUT_NAMES
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:  input_name.2: onnx::Conv_2635 shape: [128, 128, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_2636 shape: [128] dtype: float32
# INFO:  output_name.1: /backbone/body/layer2/layer2.2/conv2/Conv_output_0 shape: [1, 128, 100, 100] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_16/Relu:0 shape: (1, 100, 100, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_30/Add:0 shape: (1, 100, 100, 128) dtype: <dtype: 'float32'>
#
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/body/layer2/layer2.2/relu_1/Relu
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
